# %%
from run_deck_gen import generate_deck
from save_processing import SaveProcessor
from tqdm.notebook import tqdm as tq

# %%
grid, clean = generate_deck('input', 'output', tq)
# Out:
# Preparing pictures: 100%|██████████| 12/12 [00:00<00:00, 18.61pic/s]
# DECK: grid
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fa0f6d6c5ef6> in <module>
# ----> 1 grid, clean = generate_deck('input', 'output', tq)
#
# ~\__JetBrainsProjects\PycharmProjects\tts-deck-generator\run_deck_gen.py in generate_deck(pics_dir, output_dir, no_rejected, tqdm_inst)
#      32
#      33     print('DECK: grid')
# ---> 34     grid_deck = Deck.create(pics_face, back_images=pics_back, info=info, tqdm_inst=tqdm_inst)
#      35     print('DECK: clean')
#      36     clean_deck = Deck.create(pics_fixed, tqdm_inst=tqdm_inst)
#
# ~\__JetBrainsProjects\PycharmProjects\tts-deck-generator\deck.py in create(cls, images, info, back_img, back_images, insert_hide, hide_img, sheet_width, sheet_height, maxw, enable_tqdm, tqdm_inst)
#     100
# ...

# %%
save = "D:/Users/ZONT_/Documents/My Games/Tabletop Simulator/Saves/TS_Save_7.json"
guid = '0384f7'
guid_clean = '51db49'

p = SaveProcessor(save, guid)
p.write_decks(grid)

p.set_object(guid_clean)
p.write_decks(clean)
